# %%
from glob import glob
import cv2
import numpy as np
import matplotlib.pylab as plt

# %matplotlib inline

# %%
files = glob('inputs/train_contours/*.png')

# %%
contour1 = cv2.imread(files[0], cv2.IMREAD_GRAYSCALE)
contour2 = cv2.imread(files[1], cv2.IMREAD_GRAYSCALE)

# %%
files[0]
# Out:
# 'inputs/train_contours/0cdf5b5d0ce1_01_2_contour.png'

# %%
plt.figure(figsize=(20, 10))
plt.imshow(np.squeeze(contour1))
plt.imshow(np.squeeze(contour2), alpha=0.5, cmap='Reds')
