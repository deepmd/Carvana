# %% [markdown]
# # Carvana U-Net Heng

# %% [markdown]
# ## Imports

# %%
#from keras.optimizers import Adam
from keras.losses import binary_crossentropy
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
import tensorflow as tf
import keras.backend as K
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from optimizers.AdamAccumulate import AdamAccumulate
from models.u_net_heng import UNet_Heng
from utilities.submit import generate_submit
from utilities import utils_masks as utils
from utilities.losses import dice_value, weighted_bce_dice_loss

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Preparing Data

# %%
utils.set_results_reproducible()
input_size = 128
train_path = "inputs/train/{}.jpg" 
train_mask_path = "inputs/train_masks/{}_mask.gif"
df_train = pd.read_csv('inputs/train_masks.csv')
ids_train = df_train['img'].map(lambda s: s.split('.')[0])[:3000]
ids_train_split, ids_valid_split = train_test_split(ids_train, test_size=0.2, random_state=42)

print('Training on {} samples'.format(len(ids_train_split)))
print('Validating on {} samples'.format(len(ids_valid_split)))

bboxes = None
#bbox_file_path = 'inputs/train_bbox.csv'
#bboxes = utils.get_bboxes(bbox_file_path)

def train_generator(batch_size):
    return utils.train_generator(train_path, train_mask_path, ids_train_split, input_size, batch_size, bboxes)

def valid_generator(batch_size):
    return utils.valid_generator(train_path, train_mask_path, ids_valid_split, input_size,batch_size, bboxes)
# Out:
# Training on 2400 samples
# Validating on 600 samples

# %% [markdown]
# ## Create Model

# %%
#FC-DenseNet56:
#model = Tiramisu((input_size, input_size, 3), growth_rate=12, depth=5, layers_per_block=[4,4,4,4,4,4]) 
#FC-DenseNet67:
#model = Tiramisu((input_size, input_size, 3), growth_rate=16, depth=5, layers_per_block=[5,5,5,5,5,5]) 
#FC-DenseNet103:
#model = Tiramisu((input_size, input_size, 3), growth_rate=16, depth=5, layers_per_block=[4,5,7,10,12,15]) 
#FC-DenseNet46 (Not in paper):
#model = Tiramisu((input_size, input_size, 3), growth_rate=12, depth=4, layers_per_block=[4,4,4,4,5]) 

#U-Net:
#model = UNet((input_size, input_size, 3), filters=128, depth=4, dropout_base_only=False, dropout=0,
#             activation=lambda x: PReLU()(x),
#             init='he_uniform')
#model.compile(optimizer=AdamAccumulate(accum_iters=4), loss=weighted_bce_dice_loss, metrics=[dice_value])

#U-Net-Heng:
model = UNet_Heng((input_size, input_size, 3))
model.compile(optimizer=AdamAccumulate(accum_iters=4), loss=weighted_bce_dice_loss, metrics=[dice_value])

# %% [markdown]
# ## Fit Model

# %%
epochs = 50
batch_size = 16
run_name = utils.get_run_name('weights/{}.hdf5', 'unet-heng')
weights_path = 'weights/{}.hdf5'.format(run_name)

callbacks = [EarlyStopping(monitor='val_dice_value',
                           patience=8,
                           verbose=1,
                           min_delta=1e-4,
                           mode='max'),
             ReduceLROnPlateau(monitor='val_dice_value',
                               factor=0.1,
                               patience=4,
                               verbose=1,
                               epsilon=1e-4,
                               mode='max'),
             ModelCheckpoint(monitor='val_dice_value',
                             filepath=weights_path,
                             save_best_only=True,
                             save_weights_only=True,
                             mode='max'),
             TensorBoard(log_dir='logs/{}'.format(run_name), batch_size=batch_size)]

#model.load_weights('weights/unet-heng-2017-09-16-0946.hdf5')
#K.set_value(model.optimizer.lr, 1e-4)
#K.set_value(model.optimizer.momentum, 0.9)

print('Starting run "{}"'.format(run_name))
model.fit_generator(generator=train_generator(batch_size),
                    steps_per_epoch=np.ceil(float(len(ids_train_split)) / float(batch_size)),
                    epochs=epochs,
                    verbose=1,
                    callbacks=callbacks,
                    validation_data=valid_generator(batch_size),
                    validation_steps=np.ceil(float(len(ids_valid_split)) / float(batch_size)))
# Out:
# Starting run "unet-heng-2017-09-21-1132"
# Epoch 1/50
# 150/150 [==============================] - 117s - loss: 0.8361 - dice_value: 0.8048 - val_loss: 0.7887 - val_dice_value: 0.8875
# Epoch 2/50
# 150/150 [==============================] - 109s - loss: 0.7111 - dice_value: 0.9388 - val_loss: 0.7047 - val_dice_value: 0.9473
# Epoch 3/50
# 150/150 [==============================] - 107s - loss: 0.6887 - dice_value: 0.9661 - val_loss: 0.6814 - val_dice_value: 0.9686
# Epoch 4/50
# 150/150 [==============================] - 108s - loss: 0.6802 - dice_value: 0.9751 - val_loss: 0.6751 - val_dice_value: 0.9782
# Epoch 5/50
# 150/150 [==============================] - 108s - loss: 0.6762 - dice_value: 0.9791 - val_loss: 0.6699 - val_dice_value: 0.9813
# Epoch 6/50
# 150/150 [==============================] - 108s - loss: 0.6756 - dice_value: 0.9800 - val_loss: 0.6685 - val_dice_value: 0.9825
# Epoch 7/50
# 150/150 [==============================] - 108s - loss: 0.6717 - dice_value: 0.9827 - val_loss: 0.6637 - val_dice_value: 0.9861
# Epoch 8/50
# 150/150 [==============================] - 108s - loss: 0.6700 - dice_value: 0.9839 - val_loss: 0.6626 - val_dice_value: 0.9869
# Epoch 9/50
# 150/150 [==============================] - 108s - loss: 0.6686 - dice_value: 0.9847 - val_loss: 0.6625 - val_dice_value: 0.9875
# Epoch 10/50
# 150/150 [==============================] - 109s - loss: 0.6676 - dice_value: 0.9854 - val_loss: 0.6608 - val_dice_value: 0.9886
# Epoch 11/50
# 150/150 [==============================] - 108s - loss: 0.6668 - dice_value: 0.9859 - val_loss: 0.6603 - val_dice_value: 0.9889
# Epoch 12/50
# 150/150 [==============================] - 109s - loss: 0.6663 - dice_value: 0.9862 - val_loss: 0.6606 - val_dice_value: 0.9887
# Epoch 13/50
# 150/150 [==============================] - 109s - loss: 0.6660 - dice_value: 0.9863 - val_loss: 0.6588 - val_dice_value: 0.9897
# Epoch 14/50
# 150/150 [==============================] - 110s - loss: 0.6654 - dice_value: 0.9867 - val_loss: 0.6588 - val_dice_value: 0.9898
# Epoch 15/50
# 150/150 [==============================] - 109s - loss: 0.6648 - dice_value: 0.9868 - val_loss: 0.6571 - val_dice_value: 0.9906
# Epoch 16/50
# 150/150 [==============================] - 109s - loss: 0.6638 - dice_value: 0.9874 - val_loss: 0.6592 - val_dice_value: 0.9896
# Epoch 17/50
# 150/150 [==============================] - 109s - loss: 0.6637 - dice_value: 0.9874 - val_loss: 0.6562 - val_dice_value: 0.9908
# Epoch 18/50
# 150/150 [==============================] - 109s - loss: 0.6634 - dice_value: 0.9875 - val_loss: 0.6574 - val_dice_value: 0.9905
# Epoch 19/50
# 150/150 [==============================] - 109s - loss: 0.6629 - dice_value: 0.9878 - val_loss: 0.6557 - val_dice_value: 0.9911
# Epoch 20/50
# 150/150 [==============================] - 109s - loss: 0.6633 - dice_value: 0.9875 - val_loss: 0.6621 - val_dice_value: 0.9869
# Epoch 21/50
# 150/150 [==============================] - 106s - loss: 0.6625 - dice_value: 0.9880 - val_loss: 0.6556 - val_dice_value: 0.9913
# Epoch 22/50
# 150/150 [==============================] - 108s - loss: 0.6621 - dice_value: 0.9882 - val_loss: 0.6568 - val_dice_value: 0.9908
# Epoch 23/50
# 150/150 [==============================] - 112s - loss: 0.6624 - dice_value: 0.9881 - val_loss: 0.6547 - val_dice_value: 0.9916
# Epoch 24/50
# 150/150 [==============================] - 108s - loss: 0.6616 - dice_value: 0.9884 - val_loss: 0.6556 - val_dice_value: 0.9913
# Epoch 25/50
# 150/150 [==============================] - 109s - loss: 0.6620 - dice_value: 0.9883 - val_loss: 0.6551 - val_dice_value: 0.9915
# Epoch 26/50
# 150/150 [==============================] - 109s - loss: 0.6619 - dice_value: 0.9884 - val_loss: 0.6541 - val_dice_value: 0.9919
# Epoch 27/50
# 150/150 [==============================] - 108s - loss: 0.6612 - dice_value: 0.9886 - val_loss: 0.6549 - val_dice_value: 0.9916
# Epoch 28/50
# 150/150 [==============================] - 108s - loss: 0.6614 - dice_value: 0.9885 - val_loss: 0.6547 - val_dice_value: 0.9916
# Epoch 29/50
# 150/150 [==============================] - 109s - loss: 0.6611 - dice_value: 0.9887 - val_loss: 0.6540 - val_dice_value: 0.9919
# Epoch 30/50
# 150/150 [==============================] - 109s - loss: 0.6611 - dice_value: 0.9887 - val_loss: 0.6556 - val_dice_value: 0.9912
# Epoch 31/50
# 149/150 [============================>.] - ETA: 0s - loss: 0.6605 - dice_value: 0.9888
# Epoch 00030: reducing learning rate to 0.00010000000474974513.
# 150/150 [==============================] - 109s - loss: 0.6606 - dice_value: 0.9888 - val_loss: 0.7100 - val_dice_value: 0.9167
# Epoch 32/50
# 150/150 [==============================] - 110s - loss: 0.6595 - dice_value: 0.9893 - val_loss: 0.6520 - val_dice_value: 0.9929
# Epoch 33/50
# 150/150 [==============================] - 106s - loss: 0.6585 - dice_value: 0.9897 - val_loss: 0.6517 - val_dice_value: 0.9930
# Epoch 34/50
# 150/150 [==============================] - 100s - loss: 0.6587 - dice_value: 0.9897 - val_loss: 0.6517 - val_dice_value: 0.9930
# Epoch 35/50
# 150/150 [==============================] - 102s - loss: 0.6585 - dice_value: 0.9898 - val_loss: 0.6516 - val_dice_value: 0.9930
# Epoch 36/50
# 150/150 [==============================] - 101s - loss: 0.6585 - dice_value: 0.9898 - val_loss: 0.6516 - val_dice_value: 0.9930
# Epoch 37/50
# 150/150 [==============================] - 103s - loss: 0.6584 - dice_value: 0.9898 - val_loss: 0.6515 - val_dice_value: 0.9931
# Epoch 38/50
# 150/150 [==============================] - 102s - loss: 0.6586 - dice_value: 0.9899 - val_loss: 0.6515 - val_dice_value: 0.9931
# Epoch 39/50
# 150/150 [==============================] - 101s - loss: 0.6584 - dice_value: 0.9899 - val_loss: 0.6514 - val_dice_value: 0.9931
# Epoch 40/50
# 150/150 [==============================] - 102s - loss: 0.6586 - dice_value: 0.9898 - val_loss: 0.6514 - val_dice_value: 0.9931
# Epoch 41/50
# 150/150 [==============================] - 106s - loss: 0.6577 - dice_value: 0.9900 - val_loss: 0.6514 - val_dice_value: 0.9931
# Epoch 42/50
# 149/150 [============================>.] - ETA: 0s - loss: 0.6578 - dice_value: 0.9900
# Epoch 00041: reducing learning rate to 1.0000000474974514e-05.
# 150/150 [==============================] - 100s - loss: 0.6578 - dice_value: 0.9900 - val_loss: 0.6513 - val_dice_value: 0.9931
# Epoch 43/50
# 150/150 [==============================] - 100s - loss: 0.6583 - dice_value: 0.9898 - val_loss: 0.6512 - val_dice_value: 0.9932
# Epoch 44/50
# 150/150 [==============================] - 101s - loss: 0.6576 - dice_value: 0.9903 - val_loss: 0.6511 - val_dice_value: 0.9932
# Epoch 45/50
# 150/150 [==============================] - 101s - loss: 0.6577 - dice_value: 0.9902 - val_loss: 0.6511 - val_dice_value: 0.9932
# Epoch 46/50
# 150/150 [==============================] - 101s - loss: 0.6578 - dice_value: 0.9900 - val_loss: 0.6511 - val_dice_value: 0.9932
# Epoch 47/50
# 150/150 [==============================] - 100s - loss: 0.6579 - dice_value: 0.9900 - val_loss: 0.6511 - val_dice_value: 0.9932
# Epoch 48/50
# 149/150 [============================>.] - ETA: 0s - loss: 0.6579 - dice_value: 0.9900
# Epoch 00047: reducing learning rate to 1.0000000656873453e-06.
# 150/150 [==============================] - 101s - loss: 0.6579 - dice_value: 0.9900 - val_loss: 0.6511 - val_dice_value: 0.9932
# Epoch 49/50
# 150/150 [==============================] - 101s - loss: 0.6579 - dice_value: 0.9901 - val_loss: 0.6511 - val_dice_value: 0.9932
# Epoch 50/50
# 150/150 [==============================] - 101s - loss: 0.6577 - dice_value: 0.9902 - val_loss: 0.6511 - val_dice_value: 0.9932

# %% [markdown]
# ## Validation

# %%
def np_dice_value(y_true, y_pred):
    smooth = 1.
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

# %% [markdown]
# ### Prediction

# %%
run_name = 'unet-2017-09-02-1809'
model.load_weights('weights/{}.hdf5'.format(run_name))

val_imgs, val_masks = next(valid_generator(len(ids_valid_split)))
val_imgs = np.array(val_imgs)
val_masks = np.array(val_masks)
val_pred_masks = model.predict(val_imgs, batch_size=1)
masks_val_dices = [np_dice_value(mask, pred_mask) for (mask, pred_mask) in zip(val_masks, val_pred_masks)]

# %% [markdown]
# ### Display the worst predicted mask for validation examples

# %%
index = np.argsort(masks_val_dices)[15]
id = ids_valid_split.values[index]
utils.show_mask(train_path.format(id), val_masks[index].squeeze(), val_pred_masks[index].squeeze(), show_img=True)
print id, masks_val_dices[index]
# Out:
# 2cb06c1f5bb1_14 0.993128060848

# %%
indices = np.argsort(masks_val_dices[masks_val_dices <= 99.6])
for id in indices:
        print(masks_val_dices[id])
# Out:
# 0.996346765575

# %% [markdown]
# ### Histogram

# %%
hist, bins = np.histogram(masks_val_dices, bins=50)
width = 0.7 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:]) / 2
plt.bar(center, hist, align='center', width=width)
plt.show()

# %% [markdown]
# ### Visualization

# %%
indices = np.random.randint(len(ids_valid_split), size=3)
for index in indices:
    id = ids_valid_split.values[index]
    utils.show_mask(train_path.format(id), val_masks[index].squeeze(), val_pred_masks[index].squeeze(),
                    show_img=True, bbox = bboxes[id])

# %% [markdown]
# ## Test

# %% [markdown]
# ### Load Model

# %%
# Create model first if required
run_name = 'unet-2017-08-20-5'
model.load_weights('weights/{}.hdf5'.format(run_name))

# %% [markdown]
# ### Generate Submit

# %%
batch_size = 16
threshold = 0.5
test_path = 'inputs/test1/' #'inputs/test/'
test_masks_path = 'outputs/test1_masks/' #None
generate_submit(model, input_size, batch_size, threshold, test_path, 'outputs/', run_name, test_masks_path)

# %% [markdown]
# ### Visualization

# %%
utils.show_test_masks(test_path, test_masks_path)
